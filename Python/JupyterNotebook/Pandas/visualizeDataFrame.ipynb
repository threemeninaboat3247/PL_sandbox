# %% [markdown]
# # Visualization of a DataFrame

# %% [markdown]
# ## int values

# %%
import pandas as pd
# %matplotlib inline

origin = pd.read_csv("test.csv", sep=",")

# %%
origin.plot()

# %%
origin.shape
# Out:
# (418, 11)
